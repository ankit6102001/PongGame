# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit6102001/Python-Machine-learning-Deep-learning/blob/main/creationofdataframe_by_list_dict_exclfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame([['sonu',20,80],['monu',18,70],['ajay',22,68]])
df
# Out:
#       0   1   2
# 0  sonu  20  80
# 1  monu  18  70
# 2  ajay  22  68

# %%
df=pd.DataFrame([['sonu',20,80],['monu',18,70],['ajay',22,68]],columns=['name','age','marks'])
df
# Out:
#    name  age  marks
# 0  sonu   20     80
# 1  monu   18     70
# 2  ajay   22     68

# %%
df=pd.DataFrame([['sonu',20,80],['monu',18,70],['ajay',22,68]],columns=['name','age','marks'],index=['a','b','c'])
df
# Out:
#    name  age  marks
# a  sonu   20     80
# b  monu   18     70
# c  ajay   22     68

# %%
df=pd.DataFrame({'roll':[10,11,12],'name':['a','b','c']})
df
# Out:
#    roll name
# 0    10    a
# 1    11    b
# 2    12    c

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='cs')
df
# Out:
#    sonu  20  600
# 0  monu  18  550
# 1  ajay  22  450

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='ec')
df
# Out:
#   Name  Roll  Marks
# 0    a     1    600
# 1    b     2    400
# 2    c     3    500

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='cs',header=None)
df
# Out:
#       0   1    2
# 0  sonu  20  600
# 1  monu  18  550
# 2  ajay  22  450

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='cs',header=None,names=['name','age','marks'])
df
# Out:
#    name  age  marks
# 0  sonu   20    600
# 1  monu   18    550
# 2  ajay   22    450

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='cs',names=['name','age','marks'])
df
# Out:
#    name  age  marks
# 0  monu   18    550
# 1  ajay   22    450

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name=0,header=None,names=['name','age','marks'])
df
# Out:
#    name  age  marks
# 0  sonu   20    600
# 1  monu   18    550
# 2  ajay   22    450

# %%
df=pd.read_excel("d:/test.xlsx") #reads first sheet bydefault
df
# Out:
#    sonu  20  600
# 0  monu  18  550
# 1  ajay  22  450

# %%
dict_sheets=pd.read_excel("d:/test.xlsx",sheet_name=None)
dict_sheets.keys()
# Out:
# dict_keys(['cs', 'ec'])

# %%
df_cs=dict_sheets['cs']
df_ec=dict_sheets['ec']

# %%
df_cs
# Out:
#    sonu  20  600
# 0  monu  18  550
# 1  ajay  22  450

# %%
df_ec
# Out:
#   Name  Roll  Marks
# 0    a     1    600
# 1    b     2    400
# 2    c     3    500

# %%
df=pd.read_excel("d:/dataset/analysis/movies_sheets.xls",sheet_name='1900s')
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel("d:/dataset/analysis/movies_sheets.xls",sheet_name='1900s',nrows=50)
df
# Out:
#                                                 Title  Year  \
# 0   Intolerance: Love's Struggle Throughout the Ages   1916
# 1                     Over the Hill to the Poorhouse   1920
# 2                                     The Big Parade   1925
# 3                                         Metropolis   1927
# 4                                      Pandora's Box   1929
# 5                                The Broadway Melody   1929
# 6                                      Hell's Angels   1930
# 7                                 A Farewell to Arms   1932
# 8                                        42nd Street   1933
# 9                                 She Done Him Wrong   1933
# 10                             It Happened One Night   1934
# 11                                           Top Hat   1935
# 12                                      Modern Times   1936
# 13                   The Charge of the Light Brigade   1936
# 14                   Snow White and the Seven Dwarfs   1937
# ...

# %%
df=pd.read_excel("d:/dataset/analysis/movies_sheets.xls",sheet_name='1900s',nrows=50,skiprows=2,header=None)
df
# Out:
#                                   0     1   \
# 0    Over the Hill to the Poorhouse   1920
# 1                    The Big Parade   1925
# 2                        Metropolis   1927
# 3                     Pandora's Box   1929
# 4               The Broadway Melody   1929
# 5                     Hell's Angels   1930
# 6                A Farewell to Arms   1932
# 7                       42nd Street   1933
# 8                She Done Him Wrong   1933
# 9             It Happened One Night   1934
# 10                          Top Hat   1935
# 11                     Modern Times   1936
# 12  The Charge of the Light Brigade   1936
# 13  Snow White and the Seven Dwarfs   1937
# 14            The Prisoner of Zenda   1937
# 15         Alexander's Ragtime Band   1938
# 16       You Can't Take It with You   1938
# 17               Gone with the Wind   1939
# 18     Mr. Smith Goes to Washington   1939
# 19                 The Wizard of Oz   1939
# 20                        Boom Town   1940
# ...

# %%
df=pd.read_excel("d:/dataset/analysis/movies_sheets.xls",sheet_name='1900s',nrows=50,skiprows=[1,2])
df
# Out:
#                                Title  Year  \
# 0                    The Big Parade   1925
# 1                        Metropolis   1927
# 2                     Pandora's Box   1929
# 3               The Broadway Melody   1929
# 4                     Hell's Angels   1930
# 5                A Farewell to Arms   1932
# 6                       42nd Street   1933
# 7                She Done Him Wrong   1933
# 8             It Happened One Night   1934
# 9                           Top Hat   1935
# 10                     Modern Times   1936
# 11  The Charge of the Light Brigade   1936
# 12  Snow White and the Seven Dwarfs   1937
# 13            The Prisoner of Zenda   1937
# 14         Alexander's Ragtime Band   1938
# 15       You Can't Take It with You   1938
# 16               Gone with the Wind   1939
# 17     Mr. Smith Goes to Washington   1939
# 18                 The Wizard of Oz   1939
# 19                        Boom Town   1940
# 20                         Fantasia   1940
# ...

# %%
df=pd.read_excel("d:/dataset/analysis/movies_sheets.xls",sheet_name='1900s',nrows=50,skiprows=range(1,10))
df
# Out:
#                                Title  Year  \
# 0                She Done Him Wrong   1933
# 1             It Happened One Night   1934
# 2                           Top Hat   1935
# 3                      Modern Times   1936
# 4   The Charge of the Light Brigade   1936
# 5   Snow White and the Seven Dwarfs   1937
# 6             The Prisoner of Zenda   1937
# 7          Alexander's Ragtime Band   1938
# 8        You Can't Take It with You   1938
# 9                Gone with the Wind   1939
# 10     Mr. Smith Goes to Washington   1939
# 11                 The Wizard of Oz   1939
# 12                        Boom Town   1940
# 13                         Fantasia   1940
# 14                        Pinocchio   1940
# 15                          Rebecca   1940
# 16                    The Blue Bird   1940
# 17          How Green Was My Valley   1941
# 18                            Bambi   1942
# 19                       Casablanca   1942
# 20                  A Guy Named Joe   1943
# ...

# %%
df.head(3)
# Out:
#                     Title  Year                              Category  \
# 0     She Done Him Wrong   1933  Comedy|Drama|History|Musical|Romance
# 1  It Happened One Night   1934                        Comedy|Romance
# 2                Top Hat   1935                Comedy|Musical|Romance
#
#   Language Country Content Rating  Duration  Aspect Ratio    Budget  \
# 0  English     USA       Approved        66          1.37  200000.0
# 1  English     USA        Unrated        65          1.37  325000.0
# 2  English     USA       Approved        81          1.37  609000.0
#
#    Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0             NaN  ...                      418                       85
# 1             NaN  ...                      380                      114
# 2       3000000.0  ...                      610                      172
#
#   Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                     28.0                         583
# ...

# %%
df.head()
# Out:
#                               Title  Year  \
# 0               She Done Him Wrong   1933
# 1            It Happened One Night   1934
# 2                          Top Hat   1935
# 3                     Modern Times   1936
# 4  The Charge of the Light Brigade   1936
#
#                                Category Language Country Content Rating  \
# 0  Comedy|Drama|History|Musical|Romance  English     USA       Approved
# 1                        Comedy|Romance  English     USA        Unrated
# 2                Comedy|Musical|Romance  English     USA       Approved
# 3                   Comedy|Drama|Family  English     USA              G
# 4          Action|Adventure|Romance|War  English     USA       Approved
#
#    Duration  Aspect Ratio     Budget  Gross Earnings  ...  \
# 0        66          1.37   200000.0             NaN  ...
# 1        65          1.37   325000.0             NaN  ...
# 2        81          1.37   609000.0       3000000.0  ...
# ...

# %%
df.tail(3)
# Out:
#                              Title  Year  \
# 47  The Beast from 20,000 Fathoms   1953
# 48                       The Robe   1953
# 49   20,000 Leagues Under the Sea   1954
#
#                                  Category Language Country Content Rating  \
# 47                Adventure|Horror|Sci-Fi  English     USA       Approved
# 48                          Drama|History  English     USA        Unrated
# 49  Adventure|Drama|Family|Fantasy|Sci-Fi  English     USA       Approved
#
#     Duration  Aspect Ratio     Budget  Gross Earnings  ...  \
# 47        80          1.37   210000.0       5000000.0  ...
# 48       135          2.20  5000000.0      36000000.0  ...
# 49       127          1.37  5000000.0             NaN  ...
#
#    Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 47                       57                       40                     21.0
# 48                      726                      422                    275.0
# ...

# %%
df.tail()
# Out:
#                              Title  Year  \
# 45          From Here to Eternity   1953
# 46                        Niagara   1953
# 47  The Beast from 20,000 Fathoms   1953
# 48                       The Robe   1953
# 49   20,000 Leagues Under the Sea   1954
#
#                                  Category Language Country Content Rating  \
# 45                      Drama|Romance|War  English     USA      Not Rated
# 46               Crime|Film-Noir|Thriller  English     USA       Approved
# 47                Adventure|Horror|Sci-Fi  English     USA       Approved
# 48                          Drama|History  English     USA        Unrated
# 49  Adventure|Drama|Family|Fantasy|Sci-Fi  English     USA       Approved
#
#     Duration  Aspect Ratio     Budget  Gross Earnings  ...  \
# 45       118          1.37  1650000.0             NaN  ...
# 46        92          1.37  1250000.0             NaN  ...
# 47        80          1.37   210000.0       5000000.0  ...
# ...

# %%
df[['Year','Title']]
# Out:
#     Year                             Title
# 0   1933               She Done Him Wrong
# 1   1934            It Happened One Night
# 2   1935                          Top Hat
# 3   1936                     Modern Times
# 4   1936  The Charge of the Light Brigade
# 5   1937  Snow White and the Seven Dwarfs
# 6   1937            The Prisoner of Zenda
# 7   1938         Alexander's Ragtime Band
# 8   1938       You Can't Take It with You
# 9   1939               Gone with the Wind
# 10  1939     Mr. Smith Goes to Washington
# 11  1939                 The Wizard of Oz
# 12  1940                        Boom Town
# 13  1940                         Fantasia
# 14  1940                        Pinocchio
# 15  1940                          Rebecca
# 16  1940                    The Blue Bird
# 17  1941          How Green Was My Valley
# 18  1942                            Bambi
# 19  1942                       Casablanca
# 20  1943                  A Guy Named Joe
# ...
